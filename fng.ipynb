# %%
import numpy as np
import pandas as pd
import pandas.io.data as web

# %%
sp500 = web.DataReader('^GSPC', data_source='yahoo', 
                       start = '1/1/2000', end = '3/15/2015')

# %%
sp500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3822 entries, 2000-01-03 00:00:00 to 2015-03-13 00:00:00
# Data columns (total 6 columns):
# Open         3822 non-null float64
# High         3822 non-null float64
# Low          3822 non-null float64
# Close        3822 non-null float64
# Volume       3822 non-null int64
# Adj Close    3822 non-null float64
# dtypes: float64(5), int64(1)

# %%
# %matplotlib inline
sp500['Close'].plot(grid = True, figsize = (10, 5))

# %%
import matplotlib.pyplot as plt
plt.plot(S[:, :10])
plt.grid(True)
plt.xlabel('time step')
plt.ylabel('index level')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3b6b83e4de13> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot(S[:, :10])
#       3 plt.grid(True)
#       4 plt.xlabel('time step')
#       5 plt.ylabel('index level')
#
# NameError: name 'S' is not defined

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpld3 import *

# %%
mpld3?
# Out:
# Object `mpld3` not found.
